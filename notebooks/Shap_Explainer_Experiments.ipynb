# %% [markdown]
# **Install required packages**

# %%
# !pip install transformers
# !pip install datasets
# !pip install shap

# %% [markdown]
# **Imports**

# %%
import pandas as pd
import numpy as np
import shap
from transformers import AutoModelForSequenceClassification, AutoTokenizer, TrainingArguments, Trainer, TextClassificationPipeline
import matplotlib.pyplot as plt

# %% [markdown]
# **Import data**

# %%
data = pd.read_csv('/content/drive/MyDrive/test (1).csv')
text = list(data['text'].values)

# %% [markdown]
# **Initialize model and tokenizer**

# %%
model = AutoModelForSequenceClassification.from_pretrained('/content/drive/MyDrive/checkpoint-5000')
tokenizer = AutoTokenizer.from_pretrained('/content/drive/MyDrive/checkpoint-5000')

pipe = TextClassificationPipeline(model=model, tokenizer=tokenizer, return_all_scores=True, truncation = True, max_length = 512)

# %%
def predict_proba(sentence):
    probas = []
    for label in pipe(sentence)[0]:
        probas.append(label['score'])
    return np.array(probas)

# %%
predict_proba(text[0])
# Out:
# array([9.99979615e-01, 2.03548752e-05])

# %%
explainer = shap.Explainer(pipe)

# %%
word_attr = explainer([metrics_text[10]])
# Out:
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer: 2it [04:46, 286.95s/it]

# %%
word_attr.shape
# Out:
# (1, 1332, 2)

# %%
word_attr.shape
# Out:
# (1, 77, 2)

# %%
def faithfulness_metric(predict_proba, cls_explainer, text, tokenizer):
    # calculate word attributions
    pred_class = np.argmax(predict_proba(text))
    word_attributions = cls_explainer([text])
    coefs = []
    if word_attributions.shape[1] > 512:
      for x in word_attributions.values[0][:,pred_class][:512]:
        coefs.append(x)
    else:
      for x in word_attributions.values[0][:,pred_class]:
        coefs.append(x)
    # print(len(coefs))
    coefs = np.array(coefs[1:-1])
    tokens = np.array(tokenizer(text, truncation = True, max_length = 512)['input_ids'])[1:-1]
    base = np.zeros(tokens.shape[0])

    #find predicted class
    # pred_class = np.argmax(predict_proba(text))
    x = np.array(tokenizer(text, truncation = True, max_length = 512)['input_ids'])[1:-1]

    #find indexs of coefficients in decreasing order of value
    ar = np.argsort(-coefs)  #argsort returns indexes of values sorted in increasing order; so do it for negated array
    pred_probs = np.zeros(x.shape[0])

    for ind in np.nditer(ar):
        x_copy = x.copy()
        # print(x.shape)
        # print(base.shape)
        x_copy[ind] = base[ind]
        decoded_copy = tokenizer.decode(x_copy)
        x_copy_pr = predict_proba(decoded_copy)
        pred_probs[ind] = x_copy_pr[pred_class]

    return -np.corrcoef(coefs, pred_probs)[0,1]

# %%
def monotonicity_metric(predict_proba, cls_explainer, text, tokenizer):
    pred_class = np.argmax(predict_proba(text))
    # calculate word attributions
    word_attributions = cls_explainer([text])
    coefs = []
    print(word_attributions)
    if word_attributions.shape[1] > 512:
      for x in word_attributions.values[0][:,pred_class][:512]:
        coefs.append(x)
    else:
      for x in word_attributions.values[0][:,pred_class]:
        coefs.append(x)
    coefs = np.array(coefs[1:-1])
    tokens = np.array(tokenizer(text, truncation = True, max_length = 512)['input_ids'])[1:-1]
    base = np.zeros(tokens.shape[0])

    #find predicted class
    
    x = np.array(tokenizer(text, truncation = True, max_length = 512)['input_ids'])[1:-1]
    x_copy = base.copy()

    #find indexs of coefficients in increasing order of value
    ar = np.argsort(coefs)
    pred_probs = np.zeros(x.shape[0])
    for ind in np.nditer(ar):
        x_copy[ind] = x[ind]
        decoded_copy = tokenizer.decode(x_copy.astype(int))
        x_copy_pr = predict_proba(decoded_copy)
        pred_probs[ind] = x_copy_pr[pred_class]
    
    return np.all(np.diff(pred_probs[ar]) >= 0)

# %%
monotonicity_metric(predict_proba, explainer, text[2], tokenizer)
# Out:
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer: 2it [00:21, 21.69s/it]
# .values =
# array([[[-2.06758523e-06,  2.06632433e-06],
#         [-1.94575567e-03,  1.94575099e-03],
#         [-8.86357710e-01,  8.86357728e-01],
#         [-1.10540951e-01,  1.10540954e-01],
#         [ 1.52690245e-05, -1.52715504e-05],
#         [ 4.96730881e-05, -4.96840464e-05],
#         [ 4.54521432e-06, -4.55323038e-06],
#         [ 5.71398050e-06, -5.71728037e-06],
#         [-2.41280019e-05,  2.41345637e-05],
#         [ 5.82940459e-05, -5.82908411e-05],
#         [ 2.54351229e-05, -2.54487289e-05],
#         [ 6.87233114e-06, -6.87206773e-06],
#         [ 4.18267155e-06, -4.17842045e-06],
#         [ 2.71863246e-06, -2.71655813e-06],
#         [ 9.24591368e-05, -9.24398087e-05],
#         [-2.04254124e-04,  2.04249053e-04],
#         [-2.50128724e-05,  2.50220182e-05],
#         [-2.31840386e-06,  2.33265928e-06],
#         [-2.86491799e-04,  2.86500483e-04],
#         [ 4.83940436e-04, -4.83937390e-04],
#         [-1.31125060e-04,  1.31127762e-04],
#         [-1.09279958e-04,  1.09287475e-04],
#         [ 0.00000000e+00,  0.00000000e+00]]])
#
# .base_values =
# array([[9.99879122e-01, 1.20804580e-04]])
#
# .data =
# (array(['', 'You ', 'liar ', 'you ', 'were ', 'involved ', 'in ', 'the ',
#        'whole ', '9 ', '11 ', 'de', 'ba', 'cle ', 'I ', 'kid ', 'of ',
#        'course ', 'b', 'ou', 'nti', 'es', ''], dtype=object),)
# False

# %%
monotonicity_array = []
for t in tqdm(metrics_text):
  monotonicity_array.append(monotonicity_metric(predict_proba, explainer, t, tokenizer))

m = np.array(monotonicity_array)

print(np.mean(m))

# %%
import pickle

# %%
with open('drive/MyDrive/monotonicity_shap.pkl', 'wb') as f:
  pickle.dump(m, f)

# %%
print(m.mean())
# Out:
# 0.03

# %%
text[2]
# Out:
# 'You liar you were involved in the whole 9 11 debacle I kid of course bounties'

# %%
faithfulness_metric(predict_proba, explainer, metrics_text[10], tokenizer)
# Out:
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer: 2it [04:33, 273.81s/it]
# 0.20714245687995592

# %%
metrics_sample = pd.read_csv('drive/MyDrive/metrics_sample.csv')

# %%
metrics_text = metrics_sample['text'].values

# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (4.62.3)

# %%
from tqdm import tqdm

# %%
faithfulness_array = []
for t in tqdm(metrics_text):
  faithfulness_array.append(faithfulness_metric(predict_proba, explainer, t, tokenizer))

l = np.array(faithfulness_array)

# %%
import pickle

# %%
with open('faithfulness_shap.pkl', 'wb') as f:
  pickle.dump(l, f)

# %%
print(l.mean())
# Out:
# 0.5507082943475533

# %%
explainer = shap.Explainer(pipe)

# %%
shap_values = explainer([text[0]])
# Out:
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer: 2it [00:44, 44.39s/it]

# %%
shap_values.shape
# Out:
# (1, 30, 2)

# %%
shap_values.values[0][:,0]
# Out:
# array([ 3.52784991e-06,  2.12974846e-05,  1.15009025e-04,  4.71752137e-05,
#         3.34437937e-05,  1.91647559e-05, -1.23806298e-04,  5.88446856e-05,
#         2.36090273e-05,  2.81874090e-05,  6.93649054e-06,  3.16351652e-05,
#         2.95396894e-05,  4.51486558e-05,  1.35786831e-05,  2.77310610e-05,
#         7.80653208e-05, -5.01666218e-05,  8.50111246e-06, -7.93486834e-07,
#        -8.40853900e-05, -1.42138451e-05, -6.12065196e-06,  5.74141741e-05,
#         2.57177278e-04,  2.12183222e-04,  2.09754333e-04, -1.42399222e-05,
#        -8.85665417e-04, -5.96046448e-08])

# %%
len(tokenizer(text[0])['input_ids'])
# Out:
# 30

# %% [markdown]
# **Initialize and run explainer**

# %%
explainer = shap.Explainer(pipe)

# %%
shap_values = explainer([text])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-53943ce0b863> in <module>()
# ----> 1 shap_values = explainer([text])
#
# /usr/local/lib/python3.7/dist-packages/shap/explainers/_partition.py in __call__(self, max_evals, fixed_context, main_effects, error_bounds, batch_size, outputs, silent, *args)
#     135         return super().__call__(
#     136             *args, max_evals=max_evals, fixed_context=fixed_context, main_effects=main_effects, error_bounds=error_bounds, batch_size=batch_size,
# --> 137             outputs=outputs, silent=silent
#     138         )
#     139
#
# /usr/local/lib/python3.7/dist-packages/shap/explainers/_explainer.py in __call__(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, *args, **kwargs)
#     258             row_result = self.explain_row(
#     259                 *row_args, max_evals=max_evals, main_effects=main_effects, error_bounds=error_bounds,
# --> 260                 batch_size=batch_size, outputs=outputs, silent=silent, **kwargs
#     261             )
#     262             values.append(row_result.get("values", None))
#
# /usr/local/lib/python3.7/dist-packages/shap/explainers/_partition.py in explain_row(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, fixed_context, *row_args)
#     151
#     152         # build a masked version of the model for the current input sample
# --> 153         fm = MaskedModel(self.model, self.masker, self.link, self.linearize_link, *row_args)
#     154
#     155         # make sure we have the base value and current value outputs
#
# /usr/local/lib/python3.7/dist-packages/shap/utils/_masked_model.py in __init__(self, model, masker, link, linearize_link, *args)
#      26         # if the masker supports it, save what positions vary from the background
#      27         if callable(getattr(self.masker, "invariants", None)):
# ---> 28             self._variants = ~self.masker.invariants(*args)
#      29             self._variants_column_sums = self._variants.sum(0)
#      30             self._variants_row_inds = [
#
# /usr/local/lib/python3.7/dist-packages/shap/maskers/_text.py in invariants(self, s)
#     292         self._update_s_cache(s)
#     293
# --> 294         invariants = np.zeros(len(self._tokenized_s), dtype=np.bool)
#     295         if self.keep_prefix > 0:
#     296             invariants[:self.keep_prefix] = True
#
# TypeError: object of type 'NoneType' has no len()

# %%
def score_and_visualize(text):
  prediction = pipe([text])
  print(prediction[0])

  explainer = shap.Explainer(pipe)
  shap_values = explainer([text])

  shap.plots.text(shap_values)

# %%
shap_values = score_and_visualize(text[1250])
# Out:
# [{'label': 'LABEL_0', 'score': 0.0009607221581973135}, {'label': 'LABEL_1', 'score': 0.9990392923355103}]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer: 2it [01:10, 70.09s/it]
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
# <div align='center'>
# <script>
#     document._hover_amtsjyoxjxhqypmmsaaw = '_tp_amtsjyoxjxhqypmmsaaw_output_0';
#     document._zoom_amtsjyoxjxhqypmmsaaw = undefined;
#     function _output_onclick_amtsjyoxjxhqypmmsaaw(i) {
#         var next_id = undefined;
#
#         if (document._zoom_amtsjyoxjxhqypmmsaaw !== undefined) {
#             document.getElementById(document._zoom_amtsjyoxjxhqypmmsaaw+ '_zoom').style.display = 'none';
#
#             if (document._zoom_amtsjyoxjxhqypmmsaaw === '_tp_amtsjyoxjxhqypmmsaaw_output_' + i) {
#                 document.getElementById(document._zoom_amtsjyoxjxhqypmmsaaw).style.display = 'block';
#                 document.getElementById(document._zoom_amtsjyoxjxhqypmmsaaw+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_amtsjyoxjxhqypmmsaaw).style.display = 'none';
#                 document.getElementById(document._zoom_amtsjyoxjxhqypmmsaaw+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_amtsjyoxjxhqypmmsaaw !== '_tp_amtsjyoxjxhqypmmsaaw_output_' + i) {
#             next_id = '_tp_amtsjyoxjxhqypmmsaaw_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_amtsjyoxjxhqypmmsaaw = next_id;
#     }
#     function _output_onmouseover_amtsjyoxjxhqypmmsaaw(i, el) {
#         if (document._zoom_amtsjyoxjxhqypmmsaaw !== undefined) { return; }
#         if (document._hover_amtsjyoxjxhqypmmsaaw !== undefined) {
#             document.getElementById(document._hover_amtsjyoxjxhqypmmsaaw + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_amtsjyoxjxhqypmmsaaw).style.display = 'none';
#         }
#         document.getElementById('_tp_amtsjyoxjxhqypmmsaaw_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_amtsjyoxjxhqypmmsaaw = '_tp_amtsjyoxjxhqypmmsaaw_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_amtsjyoxjxhqypmmsaaw_output_0_name"
#     onclick="_output_onclick_amtsjyoxjxhqypmmsaaw(0)"
#     onmouseover="_output_onmouseover_amtsjyoxjxhqypmmsaaw(0, this);">LABEL_0</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_amtsjyoxjxhqypmmsaaw_output_1_name"
#     onclick="_output_onclick_amtsjyoxjxhqypmmsaaw(1)"
#     onmouseover="_output_onmouseover_amtsjyoxjxhqypmmsaaw(1, this);">LABEL_1</div><br><br><div id='_tp_amtsjyoxjxhqypmmsaaw_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="49.99999924363223%" y1="33" x2="49.99999924363223%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="49.99999924363223%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="34.57329167596645%" y1="33" x2="34.57329167596645%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="34.57329167596645%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.3</text><line x1="19.146584108300676%" y1="33" x2="19.146584108300676%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="19.146584108300676%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.1</text><line x1="65.42670681129802%" y1="33" x2="65.42670681129802%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="65.42670681129802%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.7</text><line x1="80.85341437896379%" y1="33" x2="80.85341437896379%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="80.85341437896379%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.9</text><line x1="88.52664563086317%" y1="33" x2="88.52664563086317%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="88.52664563086317%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.99948</text><text x="88.52664563086317%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.99948</text><text x="88.52664563086317%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="11.507334223409222%" y1="33" x2="11.507334223409222%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="11.507334223409222%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.000960722</text><text x="11.507334223409222%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.000960722</text><text x="11.507334223409222%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">LABEL_0</tspan>(inputs)</text><rect x="8.364482175862532%" width="3.1428520475466915%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="10.37622178144286%" x2="11.507334223409222%" y1="60" y2="60" id="_fb_nktgsoxxhphpmgefgdpw_ind_14" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="10.941778002426041%" y="71" font-size="12px" id="_fs_nktgsoxxhphpmgefgdpw_ind_14" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.015</text><svg x="10.37622178144286%" y="40" height="20" width="1.131112441966362%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">to</text>  </svg></svg><line x1="9.738678555221707%" x2="10.37622178144286%" y1="60" y2="60" id="_fb_nktgsoxxhphpmgefgdpw_ind_22" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="10.057450168332284%" y="71" font-size="12px" id="_fs_nktgsoxxhphpmgefgdpw_ind_22" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-an ...

# %%
shap_values = score_and_visualize(text[1174])
# Out:
# [{'label': 'LABEL_0', 'score': 0.0012127074878662825}, {'label': 'LABEL_1', 'score': 0.9987873435020447}]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer: 2it [00:40, 40.30s/it]
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
# <div align='center'>
# <script>
#     document._hover_cemcxayhbumwcbkynpgv = '_tp_cemcxayhbumwcbkynpgv_output_0';
#     document._zoom_cemcxayhbumwcbkynpgv = undefined;
#     function _output_onclick_cemcxayhbumwcbkynpgv(i) {
#         var next_id = undefined;
#
#         if (document._zoom_cemcxayhbumwcbkynpgv !== undefined) {
#             document.getElementById(document._zoom_cemcxayhbumwcbkynpgv+ '_zoom').style.display = 'none';
#
#             if (document._zoom_cemcxayhbumwcbkynpgv === '_tp_cemcxayhbumwcbkynpgv_output_' + i) {
#                 document.getElementById(document._zoom_cemcxayhbumwcbkynpgv).style.display = 'block';
#                 document.getElementById(document._zoom_cemcxayhbumwcbkynpgv+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_cemcxayhbumwcbkynpgv).style.display = 'none';
#                 document.getElementById(document._zoom_cemcxayhbumwcbkynpgv+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_cemcxayhbumwcbkynpgv !== '_tp_cemcxayhbumwcbkynpgv_output_' + i) {
#             next_id = '_tp_cemcxayhbumwcbkynpgv_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_cemcxayhbumwcbkynpgv = next_id;
#     }
#     function _output_onmouseover_cemcxayhbumwcbkynpgv(i, el) {
#         if (document._zoom_cemcxayhbumwcbkynpgv !== undefined) { return; }
#         if (document._hover_cemcxayhbumwcbkynpgv !== undefined) {
#             document.getElementById(document._hover_cemcxayhbumwcbkynpgv + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_cemcxayhbumwcbkynpgv).style.display = 'none';
#         }
#         document.getElementById('_tp_cemcxayhbumwcbkynpgv_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_cemcxayhbumwcbkynpgv = '_tp_cemcxayhbumwcbkynpgv_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_cemcxayhbumwcbkynpgv_output_0_name"
#     onclick="_output_onclick_cemcxayhbumwcbkynpgv(0)"
#     onmouseover="_output_onmouseover_cemcxayhbumwcbkynpgv(0, this);">LABEL_0</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_cemcxayhbumwcbkynpgv_output_1_name"
#     onclick="_output_onclick_cemcxayhbumwcbkynpgv(1)"
#     onmouseover="_output_onmouseover_cemcxayhbumwcbkynpgv(1, this);">LABEL_1</div><br><br><div id='_tp_cemcxayhbumwcbkynpgv_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="49.99999937947361%" y1="33" x2="49.99999937947361%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="49.99999937947361%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="33.332917839867456%" y1="33" x2="33.332917839867456%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="33.332917839867456%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.3</text><line x1="16.66583630026131%" y1="33" x2="16.66583630026131%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="16.66583630026131%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.1</text><line x1="66.66708091907975%" y1="33" x2="66.66708091907975%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="66.66708091907975%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.7</text><line x1="83.3341624586859%" y1="33" x2="83.3341624586859%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="83.3341624586859%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.9</text><line x1="91.65256823903326%" y1="33" x2="91.65256823903326%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="91.65256823903326%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.999818</text><text x="91.65256823903326%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.999818</text><text x="91.65256823903326%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="8.43335700337803%" y1="33" x2="8.43335700337803%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="8.43335700337803%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.00121271</text><text x="8.43335700337803%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.00121271</text><text x="8.43335700337803%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">LABEL_0</tspan>(inputs)</text><rect x="8.412098833338751%" width="0.02125817003927934%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="8.418092670854891%" x2="8.43335700337803%" y1="60" y2="60" id="_fb_ckuoqgdtizkvncdstlxe_ind_2" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="8.42572483711646%" y="71" font-size="12px" id="_fs_ckuoqgdtizkvncdstlxe_ind_2" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.0</text><svg x="8.418092670854891%" y="40" height="20" width="0.01526433252313808%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">references</text>  </svg></svg><line x1="8.415803353859767%" x2="8.418092670854891%" y1="60" y2="60" id="_fb_ckuoqgdtizkvncdstlxe_ind_28" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="8.416948012357329%" y="71" font-size="12px" id="_fs_ckuoqgdtizkvncdstlxe_ind_28" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middl ...

# %%
shap_values = score_and_visualize(text[2863])
# Out:
# [{'label': 'LABEL_0', 'score': 0.0015150128165259957}, {'label': 'LABEL_1', 'score': 0.9984850287437439}]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer: 2it [00:38, 38.60s/it]
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
# <div align='center'>
# <script>
#     document._hover_hmxkvpqvtknzqqhjuten = '_tp_hmxkvpqvtknzqqhjuten_output_0';
#     document._zoom_hmxkvpqvtknzqqhjuten = undefined;
#     function _output_onclick_hmxkvpqvtknzqqhjuten(i) {
#         var next_id = undefined;
#
#         if (document._zoom_hmxkvpqvtknzqqhjuten !== undefined) {
#             document.getElementById(document._zoom_hmxkvpqvtknzqqhjuten+ '_zoom').style.display = 'none';
#
#             if (document._zoom_hmxkvpqvtknzqqhjuten === '_tp_hmxkvpqvtknzqqhjuten_output_' + i) {
#                 document.getElementById(document._zoom_hmxkvpqvtknzqqhjuten).style.display = 'block';
#                 document.getElementById(document._zoom_hmxkvpqvtknzqqhjuten+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_hmxkvpqvtknzqqhjuten).style.display = 'none';
#                 document.getElementById(document._zoom_hmxkvpqvtknzqqhjuten+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_hmxkvpqvtknzqqhjuten !== '_tp_hmxkvpqvtknzqqhjuten_output_' + i) {
#             next_id = '_tp_hmxkvpqvtknzqqhjuten_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_hmxkvpqvtknzqqhjuten = next_id;
#     }
#     function _output_onmouseover_hmxkvpqvtknzqqhjuten(i, el) {
#         if (document._zoom_hmxkvpqvtknzqqhjuten !== undefined) { return; }
#         if (document._hover_hmxkvpqvtknzqqhjuten !== undefined) {
#             document.getElementById(document._hover_hmxkvpqvtknzqqhjuten + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_hmxkvpqvtknzqqhjuten).style.display = 'none';
#         }
#         document.getElementById('_tp_hmxkvpqvtknzqqhjuten_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_hmxkvpqvtknzqqhjuten = '_tp_hmxkvpqvtknzqqhjuten_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_hmxkvpqvtknzqqhjuten_output_0_name"
#     onclick="_output_onclick_hmxkvpqvtknzqqhjuten(0)"
#     onmouseover="_output_onmouseover_hmxkvpqvtknzqqhjuten(0, this);">LABEL_0</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_hmxkvpqvtknzqqhjuten_output_1_name"
#     onclick="_output_onclick_hmxkvpqvtknzqqhjuten(1)"
#     onmouseover="_output_onmouseover_hmxkvpqvtknzqqhjuten(1, this);">LABEL_1</div><br><br><div id='_tp_hmxkvpqvtknzqqhjuten_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="49.9999989571662%" y1="33" x2="49.9999989571662%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="49.9999989571662%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="33.330622683525604%" y1="33" x2="33.330622683525604%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="33.330622683525604%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.3</text><line x1="16.661246409885013%" y1="33" x2="16.661246409885013%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="16.661246409885013%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.1</text><line x1="66.66937523080679%" y1="33" x2="66.66937523080679%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="66.66937523080679%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.7</text><line x1="83.33875150444739%" y1="33" x2="83.33875150444739%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="83.33875150444739%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.9</text><line x1="91.65934085102006%" y1="33" x2="91.65934085102006%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="91.65934085102006%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.999831</text><text x="91.65934085102006%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.999831</text><text x="91.65934085102006%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="8.452829866555017%" y1="33" x2="8.452829866555017%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="8.452829866555017%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.00151501</text><text x="8.452829866555017%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.00151501</text><text x="8.452829866555017%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">LABEL_0</tspan>(inputs)</text><rect x="8.436157185667831%" width="0.016672680887186524%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="8.448659943603607%" x2="8.452829866555017%" y1="60" y2="60" id="_fb_dvlvvdzkavlnwfkekabq_ind_4" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="8.450744905079311%" y="71" font-size="12px" id="_fs_dvlvvdzkavlnwfkekabq_ind_4" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.0</text><svg x="8.448659943603607%" y="40" height="20" width="0.0041699229514104985%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">doing</text>  </svg></svg><line x1="8.445886594122921%" x2="8.448659943603607%" y1="60" y2="60" id="_fb_dvlvvdzkavlnwfkekabq_ind_6" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="8.447273268863263%" y="71" font-size="12px" id="_fs_dvlvvdzkavlnwfkekabq_ind_6" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor= ...

# %%
shap_values = score_and_visualize(text[317])
# Out:
# [{'label': 'LABEL_0', 'score': 0.9999827146530151}, {'label': 'LABEL_1', 'score': 1.7326206943835132e-05}]
#   0%|          | 0/210 [00:00<?, ?it/s]
# Partition explainer: 2it [00:14, 14.68s/it]
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
# <div align='center'>
# <script>
#     document._hover_muikonhvikxcrvkmajsr = '_tp_muikonhvikxcrvkmajsr_output_0';
#     document._zoom_muikonhvikxcrvkmajsr = undefined;
#     function _output_onclick_muikonhvikxcrvkmajsr(i) {
#         var next_id = undefined;
#
#         if (document._zoom_muikonhvikxcrvkmajsr !== undefined) {
#             document.getElementById(document._zoom_muikonhvikxcrvkmajsr+ '_zoom').style.display = 'none';
#
#             if (document._zoom_muikonhvikxcrvkmajsr === '_tp_muikonhvikxcrvkmajsr_output_' + i) {
#                 document.getElementById(document._zoom_muikonhvikxcrvkmajsr).style.display = 'block';
#                 document.getElementById(document._zoom_muikonhvikxcrvkmajsr+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_muikonhvikxcrvkmajsr).style.display = 'none';
#                 document.getElementById(document._zoom_muikonhvikxcrvkmajsr+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_muikonhvikxcrvkmajsr !== '_tp_muikonhvikxcrvkmajsr_output_' + i) {
#             next_id = '_tp_muikonhvikxcrvkmajsr_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_muikonhvikxcrvkmajsr = next_id;
#     }
#     function _output_onmouseover_muikonhvikxcrvkmajsr(i, el) {
#         if (document._zoom_muikonhvikxcrvkmajsr !== undefined) { return; }
#         if (document._hover_muikonhvikxcrvkmajsr !== undefined) {
#             document.getElementById(document._hover_muikonhvikxcrvkmajsr + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_muikonhvikxcrvkmajsr).style.display = 'none';
#         }
#         document.getElementById('_tp_muikonhvikxcrvkmajsr_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_muikonhvikxcrvkmajsr = '_tp_muikonhvikxcrvkmajsr_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_muikonhvikxcrvkmajsr_output_0_name"
#     onclick="_output_onclick_muikonhvikxcrvkmajsr(0)"
#     onmouseover="_output_onmouseover_muikonhvikxcrvkmajsr(0, this);">LABEL_0</div>
# <div style="display: inline; border-bottom: none; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_muikonhvikxcrvkmajsr_output_1_name"
#     onclick="_output_onclick_muikonhvikxcrvkmajsr(1)"
#     onmouseover="_output_onmouseover_muikonhvikxcrvkmajsr(1, this);">LABEL_1</div><br><br><div id='_tp_muikonhvikxcrvkmajsr_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="49.99999869928732%" y1="33" x2="49.99999869928732%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="49.99999869928732%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="39.999908516110935%" y1="33" x2="39.999908516110935%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="39.999908516110935%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.4</text><line x1="29.999818332934552%" y1="33" x2="29.999818332934552%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="29.999818332934552%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.3</text><line x1="19.999728149758166%" y1="33" x2="19.999728149758166%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="19.999728149758166%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.2</text><line x1="9.99963796658179%" y1="33" x2="9.99963796658179%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="9.99963796658179%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.1</text><line x1="60.0000888824637%" y1="33" x2="60.0000888824637%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="60.0000888824637%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.6</text><line x1="70.00017906564008%" y1="33" x2="70.00017906564008%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="70.00017906564008%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.7</text><line x1="80.00026924881648%" y1="33" x2="80.00026924881648%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="80.00026924881648%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.8</text><line x1="90.00035943199285%" y1="33" x2="90.00035943199285%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="90.00035943199285%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.9</text><line x1="99.99334467743799%" y1="33" x2="99.99334467743799%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="99.99334467743799%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.999929</text><text x="99.99334467743799%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.999929</text><text x="99.99334467743799%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="99.99872106488226%" y1="33" x2="99.99872106488226%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="99.99872106488226%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.999983</text><text x="99.99872106488226%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.999983</text><text x="99.99872106488226%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">LABEL_0</tspan>(inputs)</text><rect x="99.9927277638011%" width="0.005993301081170947%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="99.9976 ...

# %%
shap_values = score_and_visualize(text[325])
# Out:
# [{'label': 'LABEL_0', 'score': 0.9999799728393555}, {'label': 'LABEL_1', 'score': 2.0082736227777787e-05}]
#   0%|          | 0/110 [00:00<?, ?it/s]
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
# <div align='center'>
# <script>
#     document._hover_juwjflvzktizcqoriaca = '_tp_juwjflvzktizcqoriaca_output_0';
#     document._zoom_juwjflvzktizcqoriaca = undefined;
#     function _output_onclick_juwjflvzktizcqoriaca(i) {
#         var next_id = undefined;
#
#         if (document._zoom_juwjflvzktizcqoriaca !== undefined) {
#             document.getElementById(document._zoom_juwjflvzktizcqoriaca+ '_zoom').style.display = 'none';
#
#             if (document._zoom_juwjflvzktizcqoriaca === '_tp_juwjflvzktizcqoriaca_output_' + i) {
#                 document.getElementById(document._zoom_juwjflvzktizcqoriaca).style.display = 'block';
#                 document.getElementById(document._zoom_juwjflvzktizcqoriaca+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_juwjflvzktizcqoriaca).style.display = 'none';
#                 document.getElementById(document._zoom_juwjflvzktizcqoriaca+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_juwjflvzktizcqoriaca !== '_tp_juwjflvzktizcqoriaca_output_' + i) {
#             next_id = '_tp_juwjflvzktizcqoriaca_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_juwjflvzktizcqoriaca = next_id;
#     }
#     function _output_onmouseover_juwjflvzktizcqoriaca(i, el) {
#         if (document._zoom_juwjflvzktizcqoriaca !== undefined) { return; }
#         if (document._hover_juwjflvzktizcqoriaca !== undefined) {
#             document.getElementById(document._hover_juwjflvzktizcqoriaca + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_juwjflvzktizcqoriaca).style.display = 'none';
#         }
#         document.getElementById('_tp_juwjflvzktizcqoriaca_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_juwjflvzktizcqoriaca = '_tp_juwjflvzktizcqoriaca_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_juwjflvzktizcqoriaca_output_0_name"
#     onclick="_output_onclick_juwjflvzktizcqoriaca(0)"
#     onmouseover="_output_onmouseover_juwjflvzktizcqoriaca(0, this);">LABEL_0</div>
# <div style="display: inline; border-bottom: none; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_juwjflvzktizcqoriaca_output_1_name"
#     onclick="_output_onclick_juwjflvzktizcqoriaca(1)"
#     onmouseover="_output_onmouseover_juwjflvzktizcqoriaca(1, this);">LABEL_1</div><br><br><div id='_tp_juwjflvzktizcqoriaca_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="49.999996894433295%" y1="33" x2="49.999996894433295%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="49.999996894433295%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="40.000360346443514%" y1="33" x2="40.000360346443514%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="40.000360346443514%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.4</text><line x1="30.000723798453738%" y1="33" x2="30.000723798453738%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="30.000723798453738%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.3</text><line x1="20.001087250463954%" y1="33" x2="20.001087250463954%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="20.001087250463954%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.2</text><line x1="10.001450702474175%" y1="33" x2="10.001450702474175%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="10.001450702474175%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.1</text><line x1="59.999633442423075%" y1="33" x2="59.999633442423075%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="59.999633442423075%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.6</text><line x1="69.99926999041286%" y1="33" x2="69.99926999041286%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="69.99926999041286%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.7</text><line x1="79.99890653840264%" y1="33" x2="79.99890653840264%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="79.99890653840264%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.8</text><line x1="89.99854308639242%" y1="33" x2="89.99854308639242%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="89.99854308639242%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.9</text><line x1="99.99267236537503%" y1="33" x2="99.99267236537503%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="99.99267236537503%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.999945</text><text x="99.99267236537503%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.999945</text><text x="99.99267236537503%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="99.99617699110686%" y1="33" x2="99.99617699110686%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="99.99617699110686%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.99998</text><text x="99.99617699110686%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.99998</text><text x="99.99617699110686%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">LABEL_0</tspan>(inputs)</text><rect x="99.9897794100781%" width="0.006397581028758603%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><lin ...
